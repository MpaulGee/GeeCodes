# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat

# %%
data = pd.read_csv("Data.csv")

# %%
data
# Out:
#       Item  Price($)  Quantity
# 0  mangoes        10        20
# 1   apples         8        10
# 2   orange        20        15
# 3     pear        10        15
# 4   kenkey         5         2
# 5    banku        10         5
# 6     rice        15        10
# 7      yam        30         6
# 8   banana        15        12
# 9   potato         9         3

# %%
np.mean(data['Quantity'])
# Out:
# 9.8

# %%
data.Item
# Out:
# 0    mangoes
# 1     apples
# 2     orange
# 3       pear
# 4     kenkey
# 5      banku
# 6       rice
# 7        yam
# 8     banana
# 9     potato
# Name: Item, dtype: object

# %%
data.Quantity
# Out:
# 0    20
# 1    10
# 2    15
# 3    15
# 4     2
# 5     5
# 6    10
# 7     6
# 8    12
# 9     3
# Name: Quantity, dtype: int64

# %%
selected_columns = plt.plot(data['Item'], data['Price($)'])
selected_columns = plt.plot(data.Item, data.Quantity)
plt.xlabel('Item')
plt.ylabel("Price($) and Quantity")
plt.legend(["Price", "Quantity"])
plt.show()

# %%
selected_columns = plt.bar(data['Item'], data['Quantity'])
selected_columns = plt.plot(data['Item'], data['Price($)'])
plt.xlabel('Item')
plt.ylabel('Quantity and Price($)')
plt.legend(['Price', 'Quantity'])
plt.show()

# %%
min_val = min(data['Quantity'])
max_val = max(data['Quantity'])

# %%
print(f'Maxinmum value: {max_val}, Minimum value: {min_val}')
# Out:
# Maxinmum value: 20, Minimum value: 2

# %%
data.iloc[0]
# Out:
# Item        mangoes
# Price($)         10
# Quantity         20
# Name: 0, dtype: object

# %%
data.Item.iloc[0]
# Out:
# 'mangoes'

# %%
df = pd.read_csv('HDI.csv')

# %%
df
# Out:
#    Country        GDP   HDI          POP
# 0    Ghana     14,342  0.57   32,000,000
# 1   China   1,000,000  0.71  100,000,000
# 2       US  1,010,000  0.92   50,000,000
# 3  Nigeria    200,000  0.59   80,000,000
# 4     Togo      6,000  0.51   15,000,000
# 5   Norway  1,200,000  0.93   35,000,000

# %%
plt.scatter(df.Country, df.GDP)
plt.scatter(df.Country, df.HDI)
plt.scatter(df.Country, df.POP)
plt.xlabel('Country')
plt.ylabel('GDP, HDI and POP')
plt.legend(['GDP', 'HDI', 'POP'])
plt.show()

# %%
plt.plot(df.Country, df.GDP)
plt.plot(df.Country, df.HDI)
plt.plot(df.Country, df.POP)
plt.xlabel('Country')
plt.ylabel('GDP, HDI and POP')
plt.legend(['GDP', 'HDI', 'POP'])
plt.show()

# %%
plt.bar(df.Country, df.GDP)
plt.plot(df.Country, df.HDI)
plt.scatter(df.Country, df.POP)
plt.xlabel('Country')
plt.ylabel('GDP, HDI and POP')
plt.legend(['HDI', 'POP', 'GDP'])
plt.show()

# %%
temp = 30
if temp < 30:
    print('it is cold')
elif temp == 30:
    print('it is moderate')
else:
    print('it is hot')
# Out:
# it is moderate

# %%
good_credit = 10
if good_credit == 10:
    print(0.1 * 10)
else:
    print(0.2 * 10)
# Out:
# 1.0

# %%
df = [20, 10, 12, 40, 30]
price = 15

# %%
20 * 15
# Out:
# 300

# %%
x = [12, 14, 16, 18, 20]
y = [3, 6, 9, 12, 15]

# %%
plt.bar(x, y)
plt.xlabel('wheat')
plt.ylabel('tounce')
plt.title('Tounce of Wheat')
plt.show()
